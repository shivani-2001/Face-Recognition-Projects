# %%
import cv2
import face_recognition

# %%
webcam_video = cv2.VideoCapture(0)
number_of_faces = []

#loop through every frame in the video
while True:
    #get the current frame of video stream as an image
    ret, current_frame = webcam_video.read()
    #resize the current frame to 1/4 to process faster
    resize_frame = cv2.resize(current_frame, (0,0), fx=0.25, fy=0.25)
    number_of_faces = face_recognition.face_locations(resize_frame, number_of_times_to_upsample=2, model='hog')
    for index, current_face_location in enumerate(number_of_faces):
        top_pos, right_pos, bottom_pos, left_pos = current_face_location
        top_pos = top_pos*4
        right_pos = right_pos*4
        bottom_pos = bottom_pos*4
        left_pos = left_pos*4
        print("Found face {} at top:{} , right:{} , bottom:{} , left:{}".format(index+1, top_pos, right_pos,
                                                                        bottom_pos, left_pos))
        #extract the face from frame, blur it, paste it back to the frame
        current_face_image = current_frame[top_pos:bottom_pos, left_pos:right_pos]
        current_face_image = cv2.GaussianBlur(current_face_image, (99,99), 30)
        current_frame[top_pos:bottom_pos, left_pos:right_pos] = current_face_image
        cv2.rectangle(current_frame, (left_pos,top_pos), (right_pos,bottom_pos), (0,0,255), 2)
    cv2.imshow("Webcam Video", current_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam_video.release()
cv2.destroyAllWindows()
# Out:
# Found face 1 at top:152 , right:392 , bottom:256 , left:288
# Found face 1 at top:140 , right:404 , bottom:244 , left:300
# Found face 1 at top:140 , right:404 , bottom:244 , left:300
# Found face 1 at top:140 , right:404 , bottom:244 , left:300
# Found face 1 at top:140 , right:404 , bottom:244 , left:300
# Found face 1 at top:140 , right:392 , bottom:244 , left:288
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:144 , right:404 , bottom:268 , left:280
# Found face 1 at top:128 , right:416 , bottom:256 , left:292
# Found face 1 at top:144 , right:416 , bottom:268 , left:292
# Found face 1 at top:144 , right:444 , bottom:268 , left:320
# Found face 1 at top:144 , right:472 , bottom:268 , left:348
# Found face 1 at top:156 , right:500 , bottom:280 , left:376
# Found face 1 at top:156 , right:536 , bottom:308 , left:388
# Found face 1 at top:172 , right:556 , bottom:296 , left:432
# Found face 1 at top:184 , right:584 , bottom:308 , left:460
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:212 , right:624 , bottom:336 , left:500
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:540
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:208 , right:640 , bottom:356 , left:504
# Found face 1 at top:208 , right:640 , bottom:356 , left:504
# Found face 1 at top:212 , right:640 , bottom:336 , left:512
# Found face 1 at top:208 , right:640 , bottom:356 , left:504
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:228 , right:640 , bottom:352 , left:528
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:212 , right:640 , bottom:336 , left:528
# Found face 1 at top:208 , right:640 , bottom:356 , left:504
# Found face 1 at top:212 , right:640 , bottom:336 , left:512
# Found face 1 at top:212 , right:640 , bottom:336 , left:512
# Found face 1 at top:212 , right:640 , bottom:336 , left:512
# Found face 1 at top:212 , right:624 , bottom:336 , left:500
# Found face 1 at top:212 , right:624 , bottom:336 , left:500
# Found face 1 at top:212 , right:612 , bottom:336 , left:488
# Found face 1 at top:200 , right:612 , bottom:324 , left:488
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:208 , right:640 , bottom:356 , left:504
# Found face 1 at top:208 , right:640 , bottom:356 , left:504
# Found face 1 at top:208 , right:636 , bottom:356 , left:484
# Found face 1 at top:188 , right:636 , bottom:340 , left:484
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:188 , right:620 , bottom:340 , left:468
# Found face 1 at top:200 , right:612 , bottom:324 , left:488
# Found face 1 at top:172 , right:620 , bottom:324 , left:468
# Found face 1 at top:172 , right:596 , bottom:296 , left:472
# Found face 1 at top:156 , right:600 , bottom:308 , left:452
# Found face 1 at top:140 , right:584 , bottom:288 , left:436
# Found face 1 at top:156 , right:540 , bottom:280 , left:416
# Found face 1 at top:156 , right:512 , bottom:280 , left:388
# Found face 1 at top:144 , right:488 , bottom:268 , left:360
# Found face 1 at top:144 , right:460 , bottom:268 , left:336
# Found face 1 at top:144 , right:432 , bottom:268 , left:308
# Found face 1 at top:128 , right:416 , bottom:256 , left:292
# Found face 1 at top:128 , right:388 , bottom:256 , left:264
# Found face 1 at top:128 , right:388 , bottom:256 , left:264
# Found face 1 at top:124 , right:404 , bottom:272 , left:252
# Found face 1 at top:124 , right:404 , bottom:272 , left:252
# Found face 1 at top:124 , right:404 , bottom:272 , left:252
# Found face 1 at top:124 , right:420 , bottom:272 , left:268
# Found face 1 at top:128 , right:464 , bottom:308 , left:284
# Found face 1 at top:128 , right:484 , bottom:308 , left:304
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:108 , right:536 , bottom:324 , left:320
# Found face 1 at top:132 , right:536 , bottom:348 , left:320
# Found face 1 at top:132 , right:536 , bottom:348 , left:320
# Found face 1 at top:132 , right:536 , bottom:348 , left:320
# Found face 1 at top:132 , right:536 , bottom:348 , left:320
# Found face 1 at top:132 , right:536 , bottom:348 , left:320
# Found face 1 at top:148 , right:504 , bottom:328 , left:324
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:132 , right:512 , bottom:348 , left:296
# Found face 1 at top:128 , right:484 , bottom:308 , left:304
# Found face 1 at top:128 , right:484 , bottom:308 , left:304
# Found face 1 at top:128 , right:484 , bottom:308 , left:304
# Found face 1 at top:128 , right:484 , bottom:308 , left:304
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:128 , right:464 , bottom:308 , left:284
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:108 , right:484 , bottom:288 , left:304
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
# Found face 1 at top:108 , right:464 , bottom:288 , left:284
