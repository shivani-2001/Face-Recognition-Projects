# %%
import cv2
import face_recognition

# %%
webcam_video = cv2.VideoCapture('E:/Courses/Face Recognition/video1.mp4')
number_of_faces = []

#loop through every frame in the video
while True:
    #get the current frame of video stream as an image
    ret, current_frame = webcam_video.read()
    #resize the current frame to 1/4 to process faster
    resize_frame = cv2.resize(current_frame, (0,0), fx=0.25, fy=0.25)
    number_of_faces = face_recognition.face_locations(resize_frame, number_of_times_to_upsample=2, model='hog')
    for index, current_face_location in enumerate(number_of_faces):
        top_pos, right_pos, bottom_pos, left_pos = current_face_location
        top_pos = top_pos*4
        right_pos = right_pos*4
        bottom_pos = bottom_pos*4
        left_pos = left_pos*4
        print("Found face {} at top:{} , right:{} , bottom:{} , left:{}".format(index+1, top_pos, right_pos,
                                                                        bottom_pos, left_pos))
        cv2.rectangle(current_frame, (left_pos,top_pos), (right_pos,bottom_pos), (0,0,255), 2)
    cv2.imshow("Webcam Video", current_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam_video.release()
cv2.destroyAllWindows()
# Out:
# Found face 1 at top:104 , right:220 , bottom:176 , left:148
# Found face 1 at top:112 , right:220 , bottom:184 , left:148
# Found face 1 at top:112 , right:220 , bottom:184 , left:148
# Found face 1 at top:120 , right:228 , bottom:192 , left:156
# Found face 1 at top:120 , right:228 , bottom:192 , left:156
# Found face 1 at top:128 , right:228 , bottom:200 , left:156
# Found face 1 at top:128 , right:228 , bottom:200 , left:156
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# Found face 1 at top:120 , right:244 , bottom:192 , left:172
# Found face 1 at top:128 , right:252 , bottom:200 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# Found face 1 at top:116 , right:260 , bottom:204 , left:172
# Found face 1 at top:72 , right:276 , bottom:144 , left:204
# Found face 1 at top:88 , right:276 , bottom:160 , left:204
# Found face 1 at top:96 , right:276 , bottom:168 , left:204
# Found face 1 at top:104 , right:276 , bottom:176 , left:204
# Found face 1 at top:112 , right:276 , bottom:184 , left:204
# Found face 1 at top:128 , right:288 , bottom:212 , left:200
# Found face 1 at top:128 , right:276 , bottom:200 , left:204
# Found face 1 at top:128 , right:276 , bottom:200 , left:204
# Found face 1 at top:116 , right:288 , bottom:204 , left:200
# Found face 1 at top:116 , right:276 , bottom:204 , left:192
# Found face 1 at top:116 , right:276 , bottom:204 , left:192
# Found face 1 at top:116 , right:276 , bottom:204 , left:192
# Found face 1 at top:116 , right:268 , bottom:204 , left:180
# Found face 1 at top:116 , right:268 , bottom:204 , left:180
# Found face 1 at top:116 , right:268 , bottom:204 , left:180
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:96 , right:244 , bottom:168 , left:172
# Found face 1 at top:88 , right:248 , bottom:176 , left:164
# Found face 1 at top:80 , right:236 , bottom:152 , left:164
# Found face 1 at top:80 , right:240 , bottom:164 , left:152
# Found face 1 at top:68 , right:240 , bottom:156 , left:152
# Found face 1 at top:80 , right:228 , bottom:164 , left:144
# Found face 1 at top:80 , right:228 , bottom:164 , left:144
# Found face 1 at top:108 , right:220 , bottom:192 , left:132
# Found face 1 at top:120 , right:212 , bottom:192 , left:140
# Found face 1 at top:116 , right:220 , bottom:204 , left:132
# Found face 1 at top:128 , right:204 , bottom:200 , left:132
# Found face 1 at top:116 , right:212 , bottom:204 , left:124
# Found face 1 at top:116 , right:212 , bottom:204 , left:124
# Found face 1 at top:116 , right:212 , bottom:204 , left:124
# Found face 1 at top:128 , right:200 , bottom:212 , left:112
# Found face 1 at top:128 , right:200 , bottom:212 , left:112
# Found face 1 at top:128 , right:200 , bottom:212 , left:112
# Found face 1 at top:116 , right:200 , bottom:204 , left:112
# Found face 1 at top:116 , right:200 , bottom:204 , left:112
# Found face 1 at top:108 , right:212 , bottom:192 , left:124
# Found face 1 at top:108 , right:212 , bottom:192 , left:124
# Found face 1 at top:120 , right:220 , bottom:224 , left:116
# Found face 1 at top:104 , right:236 , bottom:228 , left:112
# Found face 1 at top:104 , right:236 , bottom:228 , left:112
# Found face 1 at top:104 , right:252 , bottom:228 , left:128
# Found face 1 at top:104 , right:252 , bottom:228 , left:128
# Found face 1 at top:120 , right:252 , bottom:224 , left:152
# Found face 1 at top:120 , right:252 , bottom:224 , left:152
# Found face 1 at top:120 , right:264 , bottom:224 , left:160
# Found face 1 at top:116 , right:280 , bottom:240 , left:156
# Found face 1 at top:120 , right:276 , bottom:224 , left:172
# Found face 1 at top:104 , right:292 , bottom:228 , left:168
# Found face 1 at top:120 , right:288 , bottom:224 , left:184
# Found face 1 at top:120 , right:300 , bottom:224 , left:196
# Found face 1 at top:120 , right:312 , bottom:224 , left:208
# Found face 1 at top:120 , right:312 , bottom:224 , left:208
# Found face 1 at top:116 , right:336 , bottom:240 , left:208
# Found face 1 at top:108 , right:220 , bottom:192 , left:132
# Found face 1 at top:144 , right:260 , bottom:232 , left:172
# Found face 1 at top:144 , right:260 , bottom:232 , left:172
# Found face 1 at top:144 , right:260 , bottom:232 , left:172
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# Found face 1 at top:128 , right:240 , bottom:212 , left:152
# Found face 1 at top:128 , right:248 , bottom:212 , left:164
# Found face 1 at top:120 , right:252 , bottom:224 , left:152
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# Found face 1 at top:144 , right:308 , bottom:232 , left:220
# Found face 1 at top:144 , right:308 , bottom:232 , left:220
# Found face 1 at top:144 , right:316 , bottom:232 , left:228
# Found face 1 at top:136 , right:316 , bottom:224 , left:228
# Found face 1 at top:144 , right:324 , bottom:232 , left:240
# Found face 1 at top:136 , right:324 , bottom:224 , left:240
# Found face 1 at top:144 , right:336 , bottom:232 , left:248
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 2 at top:132 , right:276 , bottom:232 , left:172
# Found face 1 at top:132 , right:356 , bottom:232 , left:252
# Found face 2 at top:120 , right:276 , bottom:224 , left:172
# Found face 1 at top:132 , right:356 , bottom:232 , left:252
# Found face 2 at top:120 , right:288 , bottom:224 , left:184
# Found face 1 at top:132 , right:368 , bottom:232 , left:264
# Found face 2 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 2 at top:132 , right:368 , bottom:232 , left:264
# Found face 1 at top:108 , right:312 , bottom:212 , left:208
# Found face 2 at top:132 , right:380 , bottom:232 , left:276
# Found face 1 at top:108 , right:312 , bottom:212 , left:208
# Found face 2 at top:132 , right:380 , bottom:232 , left:276
# Found face 1 at top:140 , right:392 , bottom:244 , left:288
# Found face 2 at top:108 , right:324 , bottom:212 , left:220
# Found face 1 at top:140 , right:392 , bottom:244 , left:288
# Found face 2 at top:128 , right:316 , bottom:212 , left:228
# Found face 1 at top:140 , right:392 , bottom:244 , left:288
# Found face 1 at top:132 , right:380 , bottom:232 , left:276
# Found face 1 at top:132 , right:380 , bottom:232 , left:276
# Found face 1 at top:128 , right:316 , bottom:200 , left:244
# Found face 1 at top:128 , right:308 , bottom:200 , left:236
# Found face 1 at top:128 , right:308 , bottom:200 , left:236
# Found face 1 at top:128 , right:308 , bottom:200 , left:236
# Found face 1 at top:136 , right:308 , bottom:208 , left:236
# Found face 1 at top:136 , right:308 , bottom:208 , left:236
# Found face 1 at top:136 , right:300 , bottom:208 , left:228
# Found face 1 at top:128 , right:292 , bottom:200 , left:220
# Found face 1 at top:120 , right:284 , bottom:192 , left:212
# Found face 1 at top:104 , right:276 , bottom:176 , left:204
# Found face 1 at top:120 , right:212 , bottom:192 , left:140
# Found face 1 at top:128 , right:204 , bottom:200 , left:132
# Found face 1 at top:136 , right:196 , bottom:208 , left:124
# Found face 1 at top:136 , right:188 , bottom:208 , left:116
# Found face 1 at top:144 , right:188 , bottom:216 , left:116
# Found face 1 at top:144 , right:180 , bottom:216 , left:108
# Found face 1 at top:136 , right:180 , bottom:208 , left:108
# Found face 1 at top:136 , right:180 , bottom:208 , left:108
# Found face 1 at top:136 , right:180 , bottom:208 , left:108
# Found face 1 at top:128 , right:180 , bottom:200 , left:108
# Found face 1 at top:136 , right:180 , bottom:208 , left:108
# Found face 1 at top:136 , right:188 , bottom:208 , left:116
# Found face 1 at top:136 , right:188 , bottom:208 , left:116
# Found face 1 at top:136 , right:188 , bottom:208 , left:116
# Found face 1 at top:136 , right:188 , bottom:208 , left:116
# Found face 1 at top:128 , right:188 , bottom:200 , left:116
# Found face 1 at top:128 , right:188 , bottom:200 , left:116
# Found face 1 at top:128 , right:180 , bottom:200 , left:108
# Found face 1 at top:128 , right:172 , bottom:200 , left:100
# Found face 1 at top:128 , right:172 , bottom:200 , left:100
# Found face 1 at top:128 , right:172 , bottom:200 , left:100
# Found face 1 at top:112 , right:204 , bottom:184 , left:132
# Found face 1 at top:112 , right:204 , bottom:184 , left:132
# Found face 1 at top:120 , right:204 , bottom:192 , left:132
# Found face 1 at top:112 , right:204 , bottom:184 , left:132
# Found face 1 at top:112 , right:204 , bottom:184 , left:132
# Found face 1 at top:120 , right:212 , bottom:192 , left:140
# Found face 1 at top:120 , right:212 , bottom:192 , left:140
# Found face 1 at top:120 , right:220 , bottom:192 , left:148
# Found face 1 at top:136 , right:228 , bottom:208 , left:156
# Found face 1 at top:136 , right:228 , bottom:208 , left:156
# Found face 1 at top:136 , right:228 , bottom:208 , left:156
# Found face 1 at top:136 , right:228 , bottom:208 , left:156
# Found face 1 at top:128 , right:228 , bottom:200 , left:156
# Found face 1 at top:120 , right:220 , bottom:192 , left:148
# Found face 1 at top:112 , right:228 , bottom:184 , left:156
# Found face 1 at top:112 , right:228 , bottom:184 , left:156
# Found face 1 at top:112 , right:228 , bottom:184 , left:156
# Found face 1 at top:120 , right:236 , bottom:192 , left:164
# Found face 1 at top:120 , right:236 , bottom:192 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# Found face 1 at top:136 , right:228 , bottom:208 , left:156
# Found face 1 at top:136 , right:228 , bottom:208 , left:156
# Found face 1 at top:128 , right:220 , bottom:200 , left:148
# Found face 1 at top:112 , right:204 , bottom:184 , left:132
# Found face 1 at top:112 , right:292 , bottom:184 , left:220
# Found face 1 at top:112 , right:292 , bottom:184 , left:220
# Found face 1 at top:112 , right:292 , bottom:184 , left:220
# Found face 1 at top:112 , right:292 , bottom:184 , left:220
# Found face 1 at top:120 , right:292 , bottom:192 , left:220
# Found face 1 at top:104 , right:284 , bottom:176 , left:212
# Found face 1 at top:112 , right:380 , bottom:184 , left:308
# Found face 1 at top:96 , right:340 , bottom:168 , left:268
# Found face 1 at top:88 , right:356 , bottom:176 , left:268
# Found face 1 at top:96 , right:356 , bottom:168 , left:284
# Found face 1 at top:96 , right:356 , bottom:168 , left:284
# Found face 1 at top:96 , right:356 , bottom:184 , left:268
# Found face 1 at top:112 , right:348 , bottom:184 , left:276
# Found face 1 at top:120 , right:348 , bottom:192 , left:276
# Found face 1 at top:120 , right:348 , bottom:192 , left:276
# Found face 1 at top:128 , right:340 , bottom:200 , left:268
# Found face 1 at top:128 , right:332 , bottom:200 , left:260
# Found face 1 at top:136 , right:332 , bottom:208 , left:260
# Found face 1 at top:136 , right:332 , bottom:208 , left:260
# Found face 1 at top:136 , right:324 , bottom:208 , left:252
# Found face 1 at top:136 , right:324 , bottom:208 , left:252
# Found face 1 at top:144 , right:316 , bottom:216 , left:244
# Found face 1 at top:144 , right:316 , bottom:216 , left:244
# Found face 1 at top:144 , right:308 , bottom:216 , left:236
# Found face 1 at top:144 , right:308 , bottom:216 , left:236
# Found face 1 at top:144 , right:300 , bottom:216 , left:228
# Found face 1 at top:144 , right:300 , bottom:216 , left:228
# Found face 1 at top:160 , right:348 , bottom:232 , left:276
# Found face 1 at top:144 , right:364 , bottom:232 , left:276
# Found face 1 at top:144 , right:364 , bottom:232 , left:276
# Found face 1 at top:144 , right:372 , bottom:232 , left:288
# Found face 1 at top:136 , right:372 , bottom:224 , left:288
# Found face 1 at top:120 , right:372 , bottom:192 , left:300
# Found face 1 at top:128 , right:372 , bottom:200 , left:300
# Found face 1 at top:128 , right:372 , bottom:212 , left:288
# Found face 1 at top:128 , right:364 , bottom:200 , left:292
# Found face 1 at top:116 , right:364 , bottom:204 , left:276
# Found face 1 at top:116 , right:364 , bottom:204 , left:276
# Found face 1 at top:116 , right:364 , bottom:204 , left:276
# Found face 1 at top:116 , right:364 , bottom:204 , left:276
# Found face 1 at top:108 , right:364 , bottom:192 , left:276
# Found face 1 at top:96 , right:368 , bottom:200 , left:264
# Found face 1 at top:80 , right:348 , bottom:152 , left:276
# Found face 1 at top:80 , right:348 , bottom:152 , left:276
# Found face 1 at top:80 , right:344 , bottom:164 , left:260
# Found face 1 at top:88 , right:344 , bottom:176 , left:260
# Found face 1 at top:96 , right:344 , bottom:184 , left:260
# Found face 1 at top:116 , right:344 , bottom:204 , left:260
# Found face 1 at top:128 , right:344 , bottom:212 , left:260
# Found face 1 at top:136 , right:344 , bottom:224 , left:260
# Found face 1 at top:136 , right:344 , bottom:224 , left:260
# Found face 1 at top:136 , right:344 , bottom:224 , left:260
# Found face 1 at top:144 , right:344 , bottom:232 , left:260
# Found face 1 at top:140 , right:356 , bottom:244 , left:252
# Found face 1 at top:140 , right:356 , bottom:244 , left:252
# Found face 1 at top:140 , right:356 , bottom:244 , left:252
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:140 , right:344 , bottom:244 , left:244
# Found face 1 at top:132 , right:336 , bottom:232 , left:232
# Found face 1 at top:132 , right:336 , bottom:232 , left:232
# Found face 1 at top:140 , right:336 , bottom:244 , left:232
# Found face 1 at top:156 , right:324 , bottom:240 , left:240
# Found face 1 at top:132 , right:324 , bottom:232 , left:220
# Found face 1 at top:132 , right:324 , bottom:232 , left:220
# Found face 1 at top:140 , right:324 , bottom:244 , left:220
# Found face 1 at top:144 , right:316 , bottom:232 , left:228
# Found face 1 at top:128 , right:316 , bottom:212 , left:228
# Found face 1 at top:136 , right:316 , bottom:224 , left:228
# Found face 1 at top:136 , right:316 , bottom:224 , left:228
# Found face 1 at top:136 , right:324 , bottom:224 , left:240
# Found face 1 at top:136 , right:324 , bottom:224 , left:240
# Found face 1 at top:136 , right:336 , bottom:224 , left:248
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:132 , right:368 , bottom:232 , left:264
# Found face 1 at top:132 , right:368 , bottom:232 , left:264
# Found face 1 at top:132 , right:368 , bottom:232 , left:264
# Found face 1 at top:144 , right:364 , bottom:232 , left:276
# Found face 1 at top:140 , right:368 , bottom:244 , left:264
# Found face 1 at top:140 , right:368 , bottom:244 , left:264
# Found face 1 at top:140 , right:356 , bottom:244 , left:252
# Found face 1 at top:132 , right:356 , bottom:232 , left:252
# Found face 1 at top:132 , right:356 , bottom:232 , left:252
# Found face 1 at top:136 , right:344 , bottom:224 , left:260
# Found face 1 at top:132 , right:344 , bottom:232 , left:244
# Found face 1 at top:136 , right:336 , bottom:224 , left:248
# Found face 1 at top:132 , right:336 , bottom:232 , left:232
# Found face 1 at top:120 , right:336 , bottom:224 , left:232
# Found face 1 at top:120 , right:324 , bottom:224 , left:220
# Found face 1 at top:120 , right:324 , bottom:224 , left:220
# Found face 1 at top:120 , right:324 , bottom:224 , left:220
# Found face 1 at top:108 , right:312 , bottom:212 , left:208
# Found face 1 at top:108 , right:312 , bottom:212 , left:208
# Found face 1 at top:108 , right:312 , bottom:212 , left:208
# Found face 1 at top:108 , right:312 , bottom:212 , left:208
# Found face 1 at top:96 , right:300 , bottom:200 , left:196
# Found face 1 at top:96 , right:300 , bottom:200 , left:196
# Found face 1 at top:96 , right:300 , bottom:200 , left:196
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:76 , right:320 , bottom:200 , left:196
# Found face 1 at top:76 , right:320 , bottom:200 , left:196
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:96 , right:312 , bottom:200 , left:208
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 1 at top:116 , right:360 , bottom:240 , left:236
# Found face 1 at top:116 , right:360 , bottom:240 , left:236
# Found face 1 at top:116 , right:360 , bottom:240 , left:236
# Found face 1 at top:116 , right:348 , bottom:240 , left:224
# Found face 1 at top:128 , right:348 , bottom:256 , left:224
# Found face 1 at top:128 , right:348 , bottom:256 , left:224
# Found face 1 at top:104 , right:280 , bottom:228 , left:156
# Found face 1 at top:92 , right:288 , bottom:240 , left:136
# Found face 1 at top:104 , right:280 , bottom:228 , left:156
# Found face 1 at top:104 , right:280 , bottom:228 , left:156
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:72 , right:304 , bottom:224 , left:152
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 1 at top:108 , right:300 , bottom:212 , left:196
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:92 , right:304 , bottom:240 , left:152
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:92 , right:320 , bottom:240 , left:172
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:104 , right:308 , bottom:228 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:92 , right:320 , bottom:240 , left:172
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:92 , right:320 , bottom:240 , left:172
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:308 , bottom:212 , left:180
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:320 , bottom:212 , left:196
# Found face 1 at top:88 , right:320 , bottom:212 , left:196
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
# Found face 1 at top:88 , right:344 , bottom:268 , left:168
