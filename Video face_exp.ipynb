# %%
import cv2
import face_recognition
import numpy as np
from keras.preprocessing import image
from keras.models import model_from_json

# %%
face_exp_model = model_from_json(open("E:/Courses/Face Recognition/facial_expression_model_structure.json",
                                      "r").read())
face_exp_model.load_weights("E:/Courses/Face Recognition/facial_expression_model_weights.h5")
emotion_label = ('angry','disgust','fear','happy','sad','surprise','neutral')

webcam_video = cv2.VideoCapture("E:/Courses/Face Recognition/video1.mp4")
number_of_faces = []

#loop through every frame in the video
while True:
    #get the current frame of video stream as an image
    ret, current_frame = webcam_video.read()
    #resize the current frame to 1/4 to process faster
    resize_frame = cv2.resize(current_frame, (0,0), fx=0.25, fy=0.25)
    number_of_faces = face_recognition.face_locations(resize_frame, number_of_times_to_upsample=2, model='hog')
    for index, current_face_location in enumerate(number_of_faces):
        top_pos, right_pos, bottom_pos, left_pos = current_face_location
        top_pos = top_pos*4
        right_pos = right_pos*4
        bottom_pos = bottom_pos*4
        left_pos = left_pos*4
        print("Found face {} at top:{} , right:{} , bottom:{} , left:{}".format(index+1, top_pos, right_pos,
                                                                        bottom_pos, left_pos))
        cv2.rectangle(current_frame, (left_pos,top_pos), (right_pos,bottom_pos), (0,0,255), 2)
        #extract the face
        current_face_image = current_frame[top_pos:bottom_pos, left_pos:right_pos]
        #preprocess the input image, convert into grayscale image
        current_face_image = cv2.cvtColor(current_face_image, cv2.COLOR_BGR2GRAY)
        #resize to 48*48 px size
        current_face_image = cv2.resize(current_face_image, (48,48))
        #convert the PIL image into numpy array
        input_image = image.img_to_array(current_face_image)
        #convert into 1d array
        input_image = np.expand_dims(input_image, axis=0)
        input_image = input_image/255
        
        expression = face_exp_model.predict(input_image)
        max_index = np.argmax(expression[0])
        print(max_index)
        emotion_label1 = emotion_label[max_index]
        
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(current_frame, emotion_label1, (left_pos,bottom_pos), font, 0.5, (255,255,255), 1)
    cv2.imshow("Webcam Video", current_frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

webcam_video.release()
cv2.destroyAllWindows()
# Out:
# Found face 1 at top:104 , right:220 , bottom:176 , left:148
# 3
# Found face 1 at top:112 , right:220 , bottom:184 , left:148
# 3
# Found face 1 at top:112 , right:220 , bottom:184 , left:148
# 3
# Found face 1 at top:120 , right:228 , bottom:192 , left:156
# 3
# Found face 1 at top:120 , right:228 , bottom:192 , left:156
# 3
# Found face 1 at top:128 , right:228 , bottom:200 , left:156
# 3
# Found face 1 at top:128 , right:228 , bottom:200 , left:156
# 3
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# 3
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# 3
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# 3
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# 3
# Found face 1 at top:128 , right:236 , bottom:200 , left:164
# 3
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# 3
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# 3
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# 3
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# 3
# Found face 1 at top:128 , right:244 , bottom:200 , left:172
# 3
# Found face 1 at top:120 , right:244 , bottom:192 , left:172
# 3
# Found face 1 at top:128 , right:252 , bottom:200 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:112 , right:252 , bottom:184 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:120 , right:252 , bottom:192 , left:180
# 3
# Found face 1 at top:116 , right:260 , bottom:204 , left:172
# 2
# Found face 1 at top:72 , right:276 , bottom:144 , left:204
# 2
# Found face 1 at top:88 , right:276 , bottom:160 , left:204
# 5
# Found face 1 at top:96 , right:276 , bottom:168 , left:204
# 5
# Found face 1 at top:104 , right:276 , bottom:176 , left:204
# 3
# Found face 1 at top:112 , right:276 , bottom:184 , left:204
# 3
# Found face 1 at top:128 , right:288 , bottom:212 , left:200
# 3
# Found face 1 at top:128 , right:276 , bottom:200 , left:204
# 3
# Found face 1 at top:128 , right:276 , bottom:200 , left:204
# 5
# Found face 1 at top:116 , right:288 , bottom:204 , left:200
# 3
# Found face 1 at top:116 , right:276 , bottom:204 , left:192
# 3
# Found face 1 at top:116 , right:276 , bottom:204 , left:192
# 3
# Found face 1 at top:116 , right:276 , bottom:204 , left:192
# 3
# Found face 1 at top:116 , right:268 , bottom:204 , left:180
# 3
# Found face 1 at top:116 , right:268 , bottom:204 , left:180
# 3
# Found face 1 at top:116 , right:268 , bottom:204 , left:180
# 3
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 3
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 3
# Found face 1 at top:96 , right:244 , bottom:168 , left:172
# 3
# Found face 1 at top:88 , right:248 , bottom:176 , left:164
# 3
# Found face 1 at top:80 , right:236 , bottom:152 , left:164
# 3
# Found face 1 at top:80 , right:240 , bottom:164 , left:152
# 3
# Found face 1 at top:68 , right:240 , bottom:156 , left:152
# 3
# Found face 1 at top:80 , right:228 , bottom:164 , left:144
# 3
# Found face 1 at top:80 , right:228 , bottom:164 , left:144
# 3
# Found face 1 at top:108 , right:220 , bottom:192 , left:132
# 3
# Found face 1 at top:120 , right:212 , bottom:192 , left:140
# 3
# Found face 1 at top:116 , right:220 , bottom:204 , left:132
# 3
# Found face 1 at top:128 , right:204 , bottom:200 , left:132
# 3
# Found face 1 at top:116 , right:212 , bottom:204 , left:124
# 3
# Found face 1 at top:116 , right:212 , bottom:204 , left:124
# 3
# Found face 1 at top:116 , right:212 , bottom:204 , left:124
# 3
# Found face 1 at top:128 , right:200 , bottom:212 , left:112
# 3
# Found face 1 at top:128 , right:200 , bottom:212 , left:112
# 3
# Found face 1 at top:128 , right:200 , bottom:212 , left:112
# 3
# Found face 1 at top:116 , right:200 , bottom:204 , left:112
# 3
# Found face 1 at top:116 , right:200 , bottom:204 , left:112
# 3
# Found face 1 at top:108 , right:212 , bottom:192 , left:124
# 3
# Found face 1 at top:108 , right:212 , bottom:192 , left:124
# 2
# Found face 1 at top:120 , right:220 , bottom:224 , left:116
# 4
# Found face 1 at top:104 , right:236 , bottom:228 , left:112
# 4
# Found face 1 at top:104 , right:236 , bottom:228 , left:112
# 3
# Found face 1 at top:104 , right:252 , bottom:228 , left:128
# 3
# Found face 1 at top:104 , right:252 , bottom:228 , left:128
# 3
# Found face 1 at top:120 , right:252 , bottom:224 , left:152
# 3
# Found face 1 at top:120 , right:252 , bottom:224 , left:152
# 3
# Found face 1 at top:120 , right:264 , bottom:224 , left:160
# 3
# Found face 1 at top:116 , right:280 , bottom:240 , left:156
# 3
# Found face 1 at top:120 , right:276 , bottom:224 , left:172
# 3
# Found face 1 at top:104 , right:292 , bottom:228 , left:168
# 3
# Found face 1 at top:120 , right:288 , bottom:224 , left:184
# 3
# Found face 1 at top:120 , right:300 , bottom:224 , left:196
# 3
# Found face 1 at top:120 , right:312 , bottom:224 , left:208
# 3
# Found face 1 at top:120 , right:312 , bottom:224 , left:208
# 0
# Found face 1 at top:116 , right:336 , bottom:240 , left:208
# 3
# Found face 1 at top:108 , right:220 , bottom:192 , left:132
# 6
# Found face 1 at top:144 , right:260 , bottom:232 , left:172
# 2
# Found face 1 at top:144 , right:260 , bottom:232 , left:172
# 4
# Found face 1 at top:144 , right:260 , bottom:232 , left:172
# 4
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# 4
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# 4
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# 4
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# 4
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# 4
# Found face 1 at top:136 , right:248 , bottom:224 , left:164
# 4
# Found face 1 at top:128 , right:240 , bottom:212 , left:152
# 3
# Found face 1 at top:128 , right:248 , bottom:212 , left:164
# 2
# Found face 1 at top:120 , right:252 , bottom:224 , left:152
# 4
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 2
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 2
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 4
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 4
# Found face 1 at top:108 , right:260 , bottom:192 , left:172
# 4
# Found face 1 at top:144 , right:308 , bottom:232 , left:220
# 3
# Found face 1 at top:144 , right:308 , bottom:232 , left:220
# 4
# Found face 1 at top:144 , right:316 , bottom:232 , left:228
# 3
